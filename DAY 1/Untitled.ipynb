# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('tycgpa.csv')

# %%
df
# Out:
#     Branch Co5.5           PRN            Stu5.5nt Name BTITC501 BTITC502  \
# 0          11246  2.154490e+12  Chaudhari Priyanshu ...      6.5        6
# 1          11246  2.154490e+12  Kothawade Tejas Sada...        6      6.5
# 2          11246  2.154490e+12        Patil Lalit Vijay        6      5.5
# 3          11246  2.154490e+12        Ahire Divya Dilip      6.5        7
# 4          11246  2.154490e+12  Ahirrao Vaishnavi Ki...        6        6
# ..           ...           ...                      ...      ...      ...
# 62         11246  2.254490e+12  Dhanashri Sanjay Cha...      6.5        7
# 63         11246  2.254490e+12      Om Shashikant Kadam      5.5        5
# 64         11246  2.254490e+12  Kalparatna Bhausaheb...      7.5        8
# 65         11246  2.254490e+12      Sushant Anan Rokade      6.5        7
# 66         11246  2.254490e+12      Jagruti Deepak Wagh      5.5        5
#
#    BTITPE503E BTITOE504D BTITL505 BTITL506  BTITP507 BTITF508
# ...

# %%
df['Total']=df['BTITC501']+	df['BTITC502']+df['BTITPE503E']+df['BTITOE504D']+df['BTITL505']+df['BTITL506']+df['BTITP507']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# ...

# %%
numeric_columns = ['BTITC501', 'BTITC502', 'BTITPE503E', 'BTITOE504D', 'BTITL505', 'BTITL506', 'BTITP507']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

df.fillna(0, inplace=True) 

df['total'] = (df['BTITC501'] + df['BTITC502'] + df['BTITPE503E'] + df['BTITOE504D'] + df['BTITL505'] + df['BTITL506'] + df['BTITP507'])/7

# Save the modified DataFrame back to CSV
df.to_csv('modified_file.csv', index=False)

# %%
df
# Out:
#     Branch Co5.5           PRN            Stu5.5nt Name  BTITC501  BTITC502  \
# 0          11246  2.154490e+12  Chaudhari Priyanshu ...       6.5       6.0
# 1          11246  2.154490e+12  Kothawade Tejas Sada...       6.0       6.5
# 2          11246  2.154490e+12        Patil Lalit Vijay       6.0       5.5
# 3          11246  2.154490e+12        Ahire Divya Dilip       6.5       7.0
# 4          11246  2.154490e+12  Ahirrao Vaishnavi Ki...       6.0       6.0
# ..           ...           ...                      ...       ...       ...
# 62         11246  2.254490e+12  Dhanashri Sanjay Cha...       6.5       7.0
# 63         11246  2.254490e+12      Om Shashikant Kadam       5.5       5.0
# 64         11246  2.254490e+12  Kalparatna Bhausaheb...       7.5       8.0
# 65         11246  2.254490e+12      Sushant Anan Rokade       6.5       7.0
# 66         11246  2.254490e+12      Jagruti Deepak Wagh       5.5       5.0
#
# ...
